# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ball_position = pd.read_csv("./res-1.csv", sep='\s+',header=None)

# %%
print(ball_position)
# Out:
#              0         1             2
# 0     0.400000  0.499019  0.000000e+00
# 1     0.500000  0.899019  0.000000e+00
# 2     0.600000  0.499019  0.000000e+00
# 3     0.400000  0.497057  0.000000e+00
# 4     0.500000  0.897057  0.000000e+00
# 5     0.600000  0.497057  0.000000e+00
# 6     0.400000  0.494114  0.000000e+00
# 7     0.500000  0.894114  0.000000e+00
# 8     0.600000  0.494114  0.000000e+00
# 9     0.400000  0.490190  0.000000e+00
# 10    0.500000  0.890190  0.000000e+00
# 11    0.600000  0.490190  0.000000e+00
# 12    0.400000  0.485285  0.000000e+00
# 13    0.500000  0.885285  0.000000e+00
# 14    0.600000  0.485285  0.000000e+00
# 15    0.400000  0.479399  0.000000e+00
# 16    0.500000  0.879399  0.000000e+00
# 17    0.600000  0.479399  0.000000e+00
# 18    0.400000  0.472532  0.000000e+00
# 19    0.500000  0.872532  0.000000e+00
# 20    0.600000  0.472532  0.000000e+00
# 21    0.400000  0.464684  0.000000e+00
# 22    0.500000  0.864684  0.000000e+00
# ...

# %%
ball_position = ball_position.values

# %%
ball0 = ball_position[0::3,:]
ball1 = ball_position[1::3,:]
ball2 = ball_position[2::3,:]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
for i in range(ball0.shape[0]):
    ax.add_patch(plt.Circle((ball0[i,0],ball0[i,1]), 0.1, color='r', alpha=0.1))
    ax.add_patch(plt.Circle((ball1[i,0],ball1[i,1]), 0.1, color='b', alpha=0.1))
    ax.add_patch(plt.Circle((ball2[i,0],ball2[i,1]), 0.1, color='g', alpha=0.1))

ax.set_aspect('equal', adjustable='datalim')
ax.plot()   #Causes an autoscale update.
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

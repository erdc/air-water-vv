# %%
# %matplotlib inline
from IPython.display import set_matplotlib_formats
#set_matplotlib_formats('svg')
import numpy as np
import matplotlib as mpl
from matplotlib  import pyplot as plt
mpl.rcParams['figure.figsize'] = "10,8"

# %%
gauges = np.genfromtxt(fname="column_gauge.csv",dtype=('d','d','d','d','d','d','d'),delimiter=',',skip_header=1,names=("t","h1","h2","h3","h4","h5","h6"))

# %%
amplitude = 0.125/2.0
waterLevel = 1.0
fig,(ax1,ax2,ax3,ax4,ax5,ax6) = plt.subplots(6,1)
ax1.plot(gauges["t"],1.5-gauges["h1"],gauges["t"],1.0+(0.125/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.125/2.0)*np.ones(gauges["t"].shape))
ax1.set_ybound(0.85,1.15)
ax2.plot(gauges["t"],1.5-gauges["h2"],
         gauges["t"],1.0+(0.125/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.125/2.0)*np.ones(gauges["t"].shape))
ax2.set_ybound(0.85,1.15)
ax3.plot(gauges["t"],1.5-gauges["h3"],gauges["t"],1.0+(0.125/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.125/2.0)*np.ones(gauges["t"].shape))
ax3.set_ybound(0.85,1.15)
ax4.plot(gauges["t"],1.5-gauges["h4"],gauges["t"],1.0+(0.125/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.125/2.0)*np.ones(gauges["t"].shape))
ax4.set_ybound(0.85,1.15)
ax5.plot(gauges["t"],1.5-gauges["h5"],gauges["t"],1.0+(0.125/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.125/2.0)*np.ones(gauges["t"].shape))
ax5.set_ybound(0.85,1.15)
ax6.plot(gauges["t"],1.5-gauges["h6"],gauges["t"],1.0+(0.125/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.125/2.0)*np.ones(gauges["t"].shape))
ax6.set_ybound(0.85,1.15)

# %%
plt.savefig("elevation_gauges.png")

# %%
plt.savefig("elevation_gauges.svg")

# %%
from tank import waves,xSponge

# %%
fig,ax = plt.subplots()
ax.plot(gauges["t"],1.5-gauges["h3"],
        gauges["t"],1.0+(0.125/2.0)*np.ones(gauges["t"].shape),
        gauges["t"],1.0-(0.125/2.0)*np.ones(gauges["t"].shape),
        gauges["t"],[1.0+waves.eta(xSponge,t) for t in gauges["t"]])

# %%
print waves.eta(0.0,0.0),waves.u(0,0.25,0.0)
# Out:
# 3.82702124734e-18 8.04405475226e-18

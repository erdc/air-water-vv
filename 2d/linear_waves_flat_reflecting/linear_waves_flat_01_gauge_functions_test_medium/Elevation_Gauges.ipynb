# %%
# %matplotlib inline
from IPython.display import set_matplotlib_formats
#set_matplotlib_formats('svg')
import numpy as np
import matplotlib as mpl
from matplotlib  import pyplot as plt
mpl.rcParams['figure.figsize'] = "8,6"

# %%
gauges = np.genfromtxt(fname="column_gauge.csv",dtype=('d','d','d','d','d'),delimiter=',',skip_header=1,names=("t","h1","h2","h3","h4"))

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4)
ax1.plot(gauges["t"],1.5-gauges["h1"],gauges["t"],1.0+(0.25/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.25/2.0)*np.ones(gauges["t"].shape))
ax1.set_ybound(0.85,1.15)
ax2.plot(gauges["t"],1.5-gauges["h2"],
         gauges["t"],1.0+(0.25/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.25/2.0)*np.ones(gauges["t"].shape))
ax2.set_ybound(0.85,1.15)
ax3.plot(gauges["t"],1.5-gauges["h3"],gauges["t"],1.0+(0.25/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.25/2.0)*np.ones(gauges["t"].shape))
ax3.set_ybound(0.85,1.15)
ax4.plot(gauges["t"],1.5-gauges["h4"],gauges["t"],1.0+(0.25/2.0)*np.ones(gauges["t"].shape),
         gauges["t"],1.0-(0.25/2.0)*np.ones(gauges["t"].shape))
ax4.set_ybound(0.85,1.15)

# %%
plt.savefig("elevation_gauges.png")

# %%
plt.savefig("elevation_gauges.svg")

# %%
from tank import waves,xSponge

# %%
fig,ax = plt.subplots()
ax.plot(gauges["t"],1.5-gauges["h2"],
        gauges["t"],1.0+(0.25/2.0)*np.ones(gauges["t"].shape),
        gauges["t"],1.0-(0.25/2.0)*np.ones(gauges["t"].shape),
        gauges["t"],[1.0+waves.eta(xSponge,t) for t in gauges["t"]])

# %%
print waves.eta(0.0,0.0),waves.u(0,0.25,0.0)
# Out:
# 7.65404249467e-18 1.60881095045e-17

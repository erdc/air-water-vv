# %%
# %matplotlib notebook
import numpy as np
from matplotlib import pyplot as plt

# %%
caisson=np.loadtxt("record_bridge.csv",delimiter=",",skiprows=1)

# %%
plt.plot(caisson[:,0],caisson[:,2])
# Out:
# <img src="data:image/png;base64,..." width="290.9090846038063">

# %%
plt.savefig("heave.png")

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import CHL_Test_Station as plant
import mpl_toolkits.mplot3d as a3
import pylab as pl
reload(plant)
import nbtools as nb
reload(nb)

domain = plant.domain
verts = []
c = []
cmap = pl.get_cmap("hsv")
ax = a3.Axes3D(pl.figure(),elev=30,azim=-20)
fN_max = float(max(domain.facetFlags))
for f, fN in zip(domain.facets[1::], domain.facetFlags[1::]):
    verts.append([domain.vertices[vN] for vN in f[0]])
    c.append(cmap(fN/(fN_max+1)))

    # for vi, vert in enumerate(c):
#     print vi,vert
ply = a3.art3d.Poly3DCollection(verts)
ply.set_facecolors(c)
ax.add_collection3d(ply)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# Out:
# (28, 28, 32, 32)
# <img src="data:image/png;base64,..." width="431.7499871328477">

# %%
domain.shape_list
